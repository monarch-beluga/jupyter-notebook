# %%
from PyRadar import Radar

# %%
k = Radar(r'F:/文件/工作/leida/', r'Z_RADR_I_Z9250_20160701001000_O_DOR_SA_CAP.bin')
# Out:
# Data has been saved in user's home directory.
# 2020-12-25 17:08:14

# %%
k.draw()

# %%
k.Elevation
# Out:
# [0.615234375,
#  0.5712890625,
#  0.5712890625,
#  0.5712890625,
#  0.5712890625,
#  0.5712890625,
#  0.5712890625,
#  0.52734375,
#  0.52734375,
#  0.52734375,
#  0.52734375,
#  0.52734375,
#  0.52734375,
#  0.4833984375,
#  0.4833984375,
#  0.4833984375,
#  0.4833984375,
#  0.4833984375,
#  0.4833984375,
#  0.4833984375,
#  0.4833984375,
#  0.4833984375,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.439453125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
#  0.3955078125,
# ...

# %%
k.surface()

# %%
k.cappi(3)

# %%
k.points()
# Out:
# E:\study\python\anaconda3\jupyter-notebook\work\PyRadar.py:250: RuntimeWarning: invalid value encountered in sqrt
#   y.append(np.sqrt(self.y[i]))
# E:\study\python\anaconda3\jupyter-notebook\work\PyRadar.py:249: RuntimeWarning: invalid value encountered in sqrt
#   x.append(np.sqrt(self.x[i]))

# %%
k.render()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-a9d71041d5ca> in <module>
# ----> 1 k.render()
#
# E:\study\python\anaconda3\jupyter-notebook\work\PyRadar.py in render(self)
#     335         volumeProperty.SetScalarOpacity(alphaChannelFunc)
#     336
# --> 337         compositeFunction = vtk.vtkVolumeRayCastCompositeFunction()
#     338         volumeMapper = vtk.vtkVolumeRayCastMapper()
#     339         volumeMapper.SetVolumeRayCastFunction(compositeFunction)
#
# AttributeError: module 'vtkmodules.all' has no attribute 'vtkVolumeRayCastCompositeFunction'
