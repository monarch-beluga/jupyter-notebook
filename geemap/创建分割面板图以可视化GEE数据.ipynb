# %%
import geemap

# %%
Map = geemap.Map()
Map.split_map() # 分割面板
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButton(value=…

# %%
Map = geemap.Map()
Map.split_map(left_layer="HYBRID", right_layer='ROADMAP') # 输入左右面板图层
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButton(value=…

# %%
basemap = geemap.ee_basemaps.keys() #查看自带的图层名称
print(basemap)
# Out:
# dict_keys(['ROADMAP', 'SATELLITE', 'TERRAIN', 'HYBRID', 'ESRI', 'Esri Ocean', 'Esri Satellite', 'Esri Standard', 'Esri Terrain', 'Esri Transportation', 'Esri Topo World', 'Esri National Geographic', 'Esri Shaded Relief', 'Esri Physical Map', 'FWS NWI Wetlands', 'FWS NWI Wetlands Raster', 'Google Maps', 'Google Satellite', 'Google Terrain', 'Google Satellite Hybrid', 'NLCD 2016 CONUS Land Cover', 'NLCD 2013 CONUS Land Cover', 'NLCD 2011 CONUS Land Cover', 'NLCD 2008 CONUS Land Cover', 'NLCD 2006 CONUS Land Cover', 'NLCD 2004 CONUS Land Cover', 'NLCD 2001 CONUS Land Cover', 'USGS NAIP Imagery', 'USGS Hydrography', 'USGS 3DEP Elevation', 'OpenStreetMap.Mapnik', 'OpenStreetMap.BlackAndWhite', 'OpenStreetMap.DE', 'OpenStreetMap.France', 'OpenStreetMap.HOT', 'OpenTopoMap', 'Hydda.Full', 'Hydda.Base', 'Esri.WorldStreetMap', 'Esri.DeLorme', 'Esri.WorldTopoMap', 'Esri.WorldImagery', 'Esri.NatGeoWorldMap', 'HikeBike.HikeBike', 'MtbMap', 'CartoDB.Positron', 'CartoDB.DarkMatter', 'NASAGIBS.Modis
# ...

# %%
Map = geemap.Map()
Map.split_map(left_layer="NLCD 2016 CONUS Land Cover", right_layer='NLCD 2001 CONUS Land Cover')
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButton(value=…

# %%
import ee # 导入gee里的地图

# %%
image = ee.ImageCollection("MODIS/006/MOD13Q1") # 查看地图id
print(image.aggregate_array('system:id').getInfo())
# Out:
# ['MODIS/006/MOD13Q1/2000_02_18', 'MODIS/006/MOD13Q1/2000_03_05', 'MODIS/006/MOD13Q1/2000_03_21', 'MODIS/006/MOD13Q1/2000_04_06', 'MODIS/006/MOD13Q1/2000_04_22', 'MODIS/006/MOD13Q1/2000_05_08', 'MODIS/006/MOD13Q1/2000_05_24', 'MODIS/006/MOD13Q1/2000_06_09', 'MODIS/006/MOD13Q1/2000_06_25', 'MODIS/006/MOD13Q1/2000_07_11', 'MODIS/006/MOD13Q1/2000_07_27', 'MODIS/006/MOD13Q1/2000_08_12', 'MODIS/006/MOD13Q1/2000_08_28', 'MODIS/006/MOD13Q1/2000_09_13', 'MODIS/006/MOD13Q1/2000_09_29', 'MODIS/006/MOD13Q1/2000_10_15', 'MODIS/006/MOD13Q1/2000_10_31', 'MODIS/006/MOD13Q1/2000_11_16', 'MODIS/006/MOD13Q1/2000_12_02', 'MODIS/006/MOD13Q1/2000_12_18', 'MODIS/006/MOD13Q1/2001_01_01', 'MODIS/006/MOD13Q1/2001_01_17', 'MODIS/006/MOD13Q1/2001_02_02', 'MODIS/006/MOD13Q1/2001_02_18', 'MODIS/006/MOD13Q1/2001_03_06', 'MODIS/006/MOD13Q1/2001_03_22', 'MODIS/006/MOD13Q1/2001_04_07', 'MODIS/006/MOD13Q1/2001_04_23', 'MODIS/006/MOD13Q1/2001_05_09', 'MODIS/006/MOD13Q1/2001_05_25', 'MODIS/006/MOD13Q1/2001_06_10', 'MODI
# ...

# %%
MODIS_2017 = ee.Image('MODIS/006/MOD13Q1/2017_01_01').select('NDVI')#导入地图和图层
MODIS_2018 = ee.Image('MODIS/006/MOD13Q1/2018_01_01').select('NDVI')

left_layer = geemap.ee_tile_layer(MODIS_2017, {}, 'MODIS_2017')
right_layer = geemap.ee_tile_layer(MODIS_2018, {}, 'MODIS_2018')

Map = geemap.Map()
Map.split_map(left_layer, right_layer)
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButton(value=…
